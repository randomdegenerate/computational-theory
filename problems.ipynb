# %%
import numpy as np
from numpy import random

# %%
arr = np.array([1,2,3,4,5])
print(arr)
print(type(arr))
# Out:
# [1 2 3 4 5]
# <class 'numpy.ndarray'>

# %%
x = 42
print(x + rtd.randint(20)) #42-62
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 x = 42
# ----> 2 print(x + rtd.randint(20)) #42-62
#
# NameError: name 'rtd' is not defined
